# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
table = pd.read_excel('R.xls')
table[1:96]
# Out:
#               Time  Energy_delta  globalnoe_gorizont_izluchenie  temperatura  \
# 1    1.1.2017 0:15             0                            0.0          1.6
# 2    1.1.2017 0:30             0                            0.0          1.6
# 3    1.1.2017 0:45             0                            0.0          1.6
# 4    1.1.2017 1:00             0                            0.0          1.7
# 5    1.1.2017 1:15             0                            0.0          1.7
# ..             ...           ...                            ...          ...
# 91  1.1.2017 22:45             0                            0.0          2.8
# 92  1.1.2017 23:00             0                            0.0          2.6
# 93  1.1.2017 23:15             0                            0.0          2.6
# 94  1.1.2017 23:30             0                            0.0          2.6
# 95  1.1.2017 23:45             0                            0.0          2.6
#
# ...

# %%
sns.lineplot(data=table[30:35], x="Time", y="Energy_delta")
# Out:
# <Axes: xlabel='Time', ylabel='Energy_delta'>

# %%
sns.pointplot(data=table[15000:15020], x="Time", y="Energy_delta")
# Out:
# <Axes: xlabel='Time', ylabel='Energy_delta'>

# %%
sns.lineplot(data=table[10000:10100], x="Wremja_solnechnogo_sveta", y="Energy_delta")
# Out:
# <Axes: xlabel='Wremja_solnechnogo_sveta', ylabel='Energy_delta'>
